# %% [markdown]
# # 🌿 Nature Adventure with Logic
# Help Melisa decide where to go hiking!

# %%
weather = input('Is it sunny, cloudy, or rainy? ').lower()
if weather == 'sunny':
    print('Perfect for a mountain hike! 🥾')
elif weather == 'cloudy':
    print('Let\'s visit the botanical garden! 🌸')
else:
    print('Time for an indoor movie marathon! 🎬')
