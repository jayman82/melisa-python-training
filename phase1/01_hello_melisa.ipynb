# %% [markdown]
# # 👋 Hello, Melisa!
# Welcome to Python with a cheer twist!
# Let's start with printing messages.

# %%
print('Let\'s go Melisa!')
print('You are a Python star! ✨')

# %% [markdown]
# ## 🎯 Your Turn
# Try writing your own cheer below!

# %%
print('Give me a P!')
print('Give me a Y!')
print('What does that spell? PYTHON!')
# Out:
# Give me a P!
# Give me a Y!
# What does that spell? PYTHON!
