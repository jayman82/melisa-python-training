# %% [markdown]
# # 🎲 Cheer Challenge Picker!
# Use Python's random module to pick a fun challenge.

# %%
import random
challenges = ['Do a 10-second cheer', 'Make up a chant', 'Create a new jump move']
pick = random.choice(challenges)
print(f'Melisa\'s challenge is: {pick}')
