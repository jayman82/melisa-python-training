# %% [markdown]
# # 💬 Cheer Machine with Functions
# Let’s build a function that cheers on your friends!

# %%
def cheer(name):
    print(f'🎉 Go {name}! You rock!')

cheer('Melisa')
cheer('Ava')

# %% [markdown]
# ## 🎯 Your Turn
# Add more names to cheer for!

# %%
# Add more calls to cheer() here!
