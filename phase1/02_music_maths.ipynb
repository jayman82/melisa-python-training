# %% [markdown]
# # 🎵 Playlist Math with Melisa
# Let's use math and input to build something cool!

# %%
songs = int(input('How many songs do you listen to each day? '))
days = int(input('How many days in a week do you want to calculate for? '))
total = songs * days
print(f'That\'s {total} songs in {days} days! 🎧')
