# %% [markdown]
# # 🎬 Melisa's Movie Night Watchlist
# Use a loop to print your top 3 movies!

# %%
movies = ['Mean Girls', 'The Princess Diaries', 'Encanto']
for movie in movies:
    print(f'Melisa wants to watch: {movie}')
