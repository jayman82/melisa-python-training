# %% [markdown]
# # 📚 Mad Libs Story Generator
# Fill in the blanks to generate a silly story!

# %%
print("Let's create a story!")
name = input("Name: ")
place = input("Place: ")
activity = input("Activity: ")
feeling = input("Feeling: ")

story = f"One day, {name} went to {place} to {activity}. It was a very {feeling} experience!"
print("\nHere's your story:")
print(story)
